# %% [markdown]
# # SyncAi Intern Assignment 4 – Boolean Comparisons

# %% [markdown]
# ### 1. Compare Digits

# %%
n = input()
print(int(n) > 25)
print(int(n[0]) > int(n[1]))

# %% [markdown]
# ### 2. Compare First Digit & Last Digit

# %%
a = input()
b = input()
print(int(a[0]) < int(b[-1]))

# %% [markdown]
# ### 3. Compare Last Three Characters

# %%
s1 = input()
s2 = input()
print(s1[-3:] == s2[-3:])

# %% [markdown]
# ### 4. Percentage of 500

# %%
p = int(input())
n = int(input())
print((p / 100) * 500 == n)

# %% [markdown]
# ### 5. Area vs Perimeter of Rectangle

# %%
l = int(input())
b = int(input())
area = l * b
perimeter = 2 * (l + b)
print(area <= perimeter)

# %% [markdown]
# ### 6. Less Than or Equal

# %%
a = int(input())
b = int(input())
print("A <= B is", a <= b)
print("B <= A is", b <= a)

# %% [markdown]
# ### 7. Profit Check

# %%
s = int(input())
b = int(input())
print(s > b)

# %% [markdown]
# ### 8. Greater than Nine

# %%
a = int(input())
b = int(input())
print(a > 9 and b > 9)

# %% [markdown]
# ### 9. Negative Numbers

# %%
a = int(input())
b = int(input())
print(a < 0 and b < 0)

# %% [markdown]
# ### 10. Positive Number

# %%
a = int(input())
b = int(input())
print(a > 0 or b > 0)

# %% [markdown]
# ### 11. Sum Not Greater than 100

# %%
a = int(input())
b = int(input())
print(a + b <= 100)

# %% [markdown]
# ### 12. Between 25 and 75

# %%
n = int(input())
print(25 < n < 75)

# %% [markdown]
# ### 13. Less than 15 (Set 2 - P1)

# %%
a = int(input())
b = int(input())
c = int(input())
print(a < 15 or b < 15 or c < 15)

# %% [markdown]
# ### 14. Not Negative (Set 2 - P2)

# %%
a = int(input())
b = int(input())
print(a >= 0 and b >= 0)

# %% [markdown]
# ### 15. Not Less than 15 (Set 2 - P3)

# %%
a = int(input())
b = int(input())
print(a >= 15 or b >= 15)

# %% [markdown]
# ### 16. Entrance (Set 2 - P4)

# %%
a = int(input())
s = input()
print(12 <= a <= 60 or s == "yes")

# %% [markdown]
# ### 17. Compare Numbers – 5 (Set 2 - P5)

# %%
a = int(input())
b = int(input())
print((a < 0 or b < 0) and (a * b >= -46))

# %% [markdown]
# ### 18. Greater than Five (Set 2 - P6)

# %%
a = int(input())
b = int(input())
print(a > 0 and b > 0 and (a > 5 or b > 5))

# %% [markdown]
# ### 19. Eligibility Criteria (Set 2 - P7)

# %%
m = int(input())
p = int(input())
c = int(input())
c1 = m >= 70 and p >= 60 and c >= 60
c2 = m + p + c >= 180
print(c1 or c2)

# %% [markdown]
# ### 20. Compare with Ten (Set 2 - P8)

# %%
a = int(input())
b = int(input())
c1 = a + b < 10
c2 = abs(a - b) < 10
c3 = a > 5 and a < 30
print(c1 or c2 or c3)

# %% [markdown]
# ### 21. Same Digits (Set 3 - P1)

# %%
n = input()
print(n[0] == n[1] == n[2])

# %% [markdown]
# ### 22. Sum and Product Check – 2 (Set 3 - P2)

# %%
a = int(input())
b = int(input())
print(a + b < 0 or a * b < 0)

# %% [markdown]
# ### 23. Valid Triangle (Set 3 - P3)

# %%
a = int(input())
b = int(input())
c = int(input())
print((a + b > c) and (b + c > a) and (a + c > b))

# %% [markdown]
# ### 24. Required Number (Set 3 - P4)

# %%
n = input()
print(50 < int(n) < 100 or n[0] == '7')

# %% [markdown]
# ### 25. Compare Numbers – 10 (Set 3 - P5)

# %%
a = int(input())
b = int(input())
c1 = a < 20 or b < 20
c2 = a > 30 or b > 30
print(c1 and c2)

# %% [markdown]
# ### 26. Eligibility Criteria – 3 (Set 3 - P6)

# %%
m = int(input())
p = int(input())
c = int(input())
c1 = m >= 35 and p >= 35 and c >= 35
c2 = (m + p >= 90) or (p + c >= 90) or (m + c >= 90)
print(c1 and c2)

# %% [markdown]
# ### 27. Eligibility Criteria – 4 (Set 3 - P7)

# %%
m = int(input())
p = int(input())
c = int(input())
c1 = m >= 60 and p >= 50 and c >= 45 and (m + p + c >= 180)
c2 = (m + p >= 120) or (c + p >= 110)
print(c1 or c2)
